# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipython==8.4.0
#   Downloading ipython-8.4.0-py3-none-any.whl (750 kB)
#      |████████████████████████████████| 750 kB 981 kB/s eta 0:00:01
# Collecting matplotlib==3.5.2
#   Downloading matplotlib-3.5.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 5.6 MB/s eta 0:00:01    |███▉                            | 1.3 MB 2.3 MB/s eta 0:00:05
# Collecting numpy==1.23.1
#   Downloading numpy-1.23.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 7.5 MB/s eta 0:00:01     |█████████████████████████▋      | 13.7 MB 7.5 MB/s eta 0:00:01
# Collecting pandas==1.4.3
#   Downloading pandas-1.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 6.7 MB/s eta 0:00:01    |██████████████▍                 | 5.2 MB 6.2 MB/s eta 0:00:02
# Collecting plotly==5.9.0
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      |████████████████████████████████| 15.2 MB 9.3 MB/s eta 0:00:01     |██████████████████████▉         | 10.8 MB 6.1 MB/s eta 0:00:01
# Collecting scikit_learn==1.1.1
#   Downloading scikit_learn-1.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
#      |████████████████████████████████| 30.8 MB 9.9 MB/s eta 0:00:01     |████████████████████████▉       | 23.9 MB 3.9 MB/s eta 0:00:02     |██████████████████████████      | 24.9 MB 3.9 MB/s eta 0:00:02
# Requirement already satisfied: seaborn==0.11.2 in /anaconda/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.11.2)
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      |████████████████████████████████| 572 kB 6.1 MB/s eta 0:00:01
# Collecting streamlit==1.11.1
#   Downloading streamlit-1.11.1-py2.py3-none-any.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 6.9 MB/s eta 0:00:01     |████████▊                       | 2.5 MB 6.3 MB/s eta 0:00:02
# Requirement already satisfied: backcall in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (3.0.20)
# Requirement already satisfied: decorator in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: pygments>=2.4.0 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (58.0.4)
# Requirement already satisfied: pexpect>4.3 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.18.0)
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: pickleshare in /anaconda/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: packaging>=20.0 in /home/feynman/.local/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/lib/python3.9/site-packages (from pandas==1.4.3->-r requirements.txt (line 4)) (2021.3)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /anaconda/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /anaconda/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.7.1)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      |████████████████████████████████| 35.9 MB 4.2 MB/s eta 0:00:01    |█                               | 1.1 MB 4.7 MB/s eta 0:00:08     |██████████████████████          | 24.7 MB 4.0 MB/s eta 0:00:03     |████████████████████████████▋   | 32.0 MB 7.5 MB/s eta 0:00:01ta 0:00:01
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=2.4 in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.26.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 2.6 MB/s eta 0:00:01
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 5.6 MB/s eta 0:00:01
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=5.0 in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (6.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.8.1)
# Requirement already satisfied: attrs>=16.0.0 in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (21.2.0)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 5.9 MB/s eta 0:00:01
# Requirement already satisfied: click>=7.0 in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (8.0.3)
# Requirement already satisfied: toml in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (0.10.2)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.7 MB/s eta 0:00:01     |█████████████                   | 1.9 MB 5.7 MB/s eta 0:00:01     |██████████████████████████▊     | 3.9 MB 5.7 MB/s eta 0:00:01
# Requirement already satisfied: watchdog in /anaconda/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/feynman/.local/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.4.0)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.1 MB/s eta 0:00:01     |██████████████████████▌         | 716 kB 6.1 MB/s eta 0:00:01
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm>4.25.0 in /anaconda/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (4.62.3)
# Requirement already satisfied: cloudpickle in /anaconda/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: numba in /anaconda/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (0.54.1)
# Requirement already satisfied: jinja2 in /anaconda/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (2.11.3)
# Requirement already satisfied: entrypoints in /anaconda/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in /anaconda/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: toolz in /anaconda/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.11.1)
# Requirement already satisfied: six in /anaconda/lib/python3.9/site-packages (from cycler>=0.10->matplotlib==3.5.2->-r requirements.txt (line 2)) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /anaconda/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /anaconda/lib/python3.9/site-packages (from jedi>=0.16->ipython==8.4.0->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/lib/python3.9/site-packages (from pexpect>4.3->ipython==8.4.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==8.4.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /anaconda/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2021.10.8)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 5.1 MB/s eta 0:00:01
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      |████████████████████████████████| 33.8 MB 7.0 MB/s eta 0:00:011    |█████████▉                      | 10.4 MB 5.4 MB/s eta 0:00:05     |█████████████████               | 17.9 MB 2.6 MB/s eta 0:00:07     |█████████████████████████▋      | 27.1 MB 11.7 MB/s eta 0:00:01     |██████████████████████████▊     | 28.2 MB 11.7 MB/s eta 0:00:01
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /anaconda/lib/python3.9/site-packages (from numba->shap->-r requirements.txt (line 8)) (0.37.0)
# Collecting numba
#   Downloading numba-0.56.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 2.2 MB/s eta 0:00:01
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 276 kB/s eta 0:00:01     |███████████████                 | 16.3 MB 5.6 MB/s eta 0:00:04     |████████████████████████▏       | 26.1 MB 6.2 MB/s eta 0:00:02
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      |████████████████████████████████| 340 kB 3.1 MB/s eta 0:00:01
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.0-py2.py3-none-any.whl (26 kB)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19583 sha256=bf2a65120eae98feac51c878a1a15c703ce13ccb2b457333bdc2adf98b27873d
#   Stored in directory: /home/feynman/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: tzdata, smmap, numpy, scipy, pytz-deprecation-shim, pure-eval, pandas, llvmlite, gitdb, executing, commonmark, asttokens, validators, tzlocal, tenacity, stack-data, slicer, semver, scikit-learn, rich, pympler, pydeck, pyarrow, protobuf, numba, matplotlib, gitpython, cachetools, blinker, altair, streamlit, shap, plotly, ipython
#   WARNING: The scripts f2py, f2py3 and f2py3.9 are installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script cmark is installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pysemver is installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script plasma_store is installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit is installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ipython and ipython3 are installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# ipykernel 6.4.1 requires ipython<8.0,>=7.23.1, but you have ipython 8.4.0 which is incompatible.
# Successfully installed altair-4.2.0 asttokens-2.2.0 blinker-1.5 cachetools-5.2.0 commonmark-0.9.1 executing-1.2.0 gitdb-4.0.10 gitpython-3.1.29 ipython-8.4.0 llvmlite-0.39.1 matplotlib-3.5.2 numba-0.56.4 numpy-1.23.1 pandas-1.4.3 plotly-5.9.0 protobuf-3.20.3 pure-eval-0.2.2 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.6.0 scikit-learn-1.1.1 scipy-1.9.3 semver-2.13.0 shap-0.41.0 slicer-0.0.7 smmap-5.0.0 stack-data-0.6.2 streamlit-1.11.1 tenacity-8.1.0 tzdata-2022.7 tzlocal-4.2 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tpot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 2.9 MB/s eta 0:00:01
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.7.1-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      |████████████████████████████████| 193.6 MB 94 kB/s  eta 0:00:01    |███▎                            | 19.8 MB 4.3 MB/s eta 0:00:41     |█████                           | 30.0 MB 6.0 MB/s eta 0:00:28     |██████▏                         | 37.4 MB 10.0 MB/s eta 0:00:16     |█████████▊                      | 58.8 MB 3.7 MB/s eta 0:00:37     |██████████▌                     | 63.7 MB 6.5 MB/s eta 0:00:21     |██████████▉                     | 65.5 MB 6.5 MB/s eta 0:00:20     |███████████▋                    | 70.2 MB 4.2 MB/s eta 0:00:30     |████████████▋                   | 76.2 MB 5.9 MB/s eta 0:00:21     |█████████████▌                  | 81.4 MB 7.0 MB/s eta 0:00:17     |█████████████████▉              | 108.0 MB 6.9 MB/s eta 0:00:13     |██████████████████▍             | 110.9 MB 6.9 MB/s eta 0:00:12     |██████████████████▊             | 113.5 MB 6.9 MB/s eta 0:00:12     |█████████████████████████▎      | 152.6 MB 3.6 MB/s eta 0:00:12     |█████████████████████████▎      | 153.0 MB 3.6 MB/s eta 0:00:12     |███████████████████████████▌    | 166.3 MB 4.8 MB/s eta 0:00:06     |███████████████████████████▊    | 167.6 MB 4.8 MB/s eta 0:00:06     |█████████████████████████████▎  | 177.3 MB 4.9 MB/s eta 0:00:04     |█████████████████████████████▉  | 180.5 MB 4.9 MB/s eta 0:00:03
# Requirement already satisfied: joblib>=0.13.2 in /anaconda/lib/python3.9/site-packages (from tpot) (1.1.0)
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      |████████████████████████████████| 139 kB 5.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3.1 in /home/feynman/.local/lib/python3.9/site-packages (from tpot) (1.9.3)
# Requirement already satisfied: numpy>=1.16.3 in /home/feynman/.local/lib/python3.9/site-packages (from tpot) (1.23.1)
# Requirement already satisfied: tqdm>=4.36.1 in /anaconda/lib/python3.9/site-packages (from tpot) (4.62.3)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/feynman/.local/lib/python3.9/site-packages (from tpot) (1.1.1)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: pandas>=0.24.2 in /home/feynman/.local/lib/python3.9/site-packages (from tpot) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /anaconda/lib/python3.9/site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/lib/python3.9/site-packages (from pandas>=0.24.2->tpot) (2021.3)
# Requirement already satisfied: six>=1.5 in /anaconda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/lib/python3.9/site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: requests>=2.3.0 in /anaconda/lib/python3.9/site-packages (from update-checker>=0.16->tpot) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /anaconda/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.7)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11952 sha256=4603d74eed6cfb95598a0c9e5cfe7f671ce498cbc1e731e3575f26bdd6f866b2
#   Stored in directory: /home/feynman/.cache/pip/wheels/48/8c/93/3afb1916772591fe6bcc25cdf8b1c5bdc362f0ec8e2f0fd413
# Successfully built stopit
# Installing collected packages: xgboost, update-checker, stopit, deap, tpot
#   WARNING: The script tpot is installed in '/home/feynman/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed deap-1.3.3 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0 xgboost-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import plotly 
import sklearn 
import shap
import tpot
import streamlit as st
# Out:
# Warning: optional dependency `torch` is not available. - skipping import of NN models.
